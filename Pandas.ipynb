# %%
#  its a library

# %%
import pandas as pd

# %%
pd.read_csv('sample_test.csv')
# Out:
#        name    emailid address  pincode sirname
# 0    aditya      a@1.c   kanke   834006    aman
# 1      aman      b@2.c  ranchi   834001     lol
# 2  ass;ljf;  dla;slkas  spkpsf   563566

# %%
pd.read_csv('123.csv')
# Out:
#      Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0       BDCQ.SF1AA2CA  2016.06    1116.386         NaN      F  Dollars
# 1       BDCQ.SF1AA2CA  2016.09    1070.874         NaN      F  Dollars
# 2       BDCQ.SF1AA2CA  2016.12    1054.408         NaN      F  Dollars
# 3       BDCQ.SF1AA2CA  2017.03    1010.665         NaN      F  Dollars
# 4       BDCQ.SF1AA2CA  2017.06    1233.700         NaN      F  Dollars
# ...               ...      ...         ...         ...    ...      ...
# 5435     BDCQ.SF8RSCA  2020.12     522.330         NaN      F  Dollars
# 5436     BDCQ.SF8RSCA  2021.03     597.997         NaN      F  Dollars
# 5437     BDCQ.SF8RSCA  2021.06     635.931         NaN      F  Dollars
# 5438     BDCQ.SF8RSCA  2021.09     382.195         NaN      R  Dollars
# 5439     BDCQ.SF8RSCA  2021.12     397.184         NaN      F  Dollars
#
#       Magnitude                         Subject  \
# 0             6  Business Data Collection - BDC
# ...

# %%
import pandas as lol

# %%
lol.read_csv('123.csv')
# Out:
#      Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0       BDCQ.SF1AA2CA  2016.06    1116.386         NaN      F  Dollars
# 1       BDCQ.SF1AA2CA  2016.09    1070.874         NaN      F  Dollars
# 2       BDCQ.SF1AA2CA  2016.12    1054.408         NaN      F  Dollars
# 3       BDCQ.SF1AA2CA  2017.03    1010.665         NaN      F  Dollars
# 4       BDCQ.SF1AA2CA  2017.06    1233.700         NaN      F  Dollars
# ...               ...      ...         ...         ...    ...      ...
# 5435     BDCQ.SF8RSCA  2020.12     522.330         NaN      F  Dollars
# 5436     BDCQ.SF8RSCA  2021.03     597.997         NaN      F  Dollars
# 5437     BDCQ.SF8RSCA  2021.06     635.931         NaN      F  Dollars
# 5438     BDCQ.SF8RSCA  2021.09     382.195         NaN      R  Dollars
# 5439     BDCQ.SF8RSCA  2021.12     397.184         NaN      F  Dollars
#
#       Magnitude                         Subject  \
# 0             6  Business Data Collection - BDC
# ...

# %%
pd.read_csv('sample_test.csv')
# Out:
#        name    emailid address  pincode sirname
# 0    aditya      a@1.c   kanke   834006    aman
# 1      aman      b@2.c  ranchi   834001     lol
# 2  ass;ljf;  dla;slkas  spkpsf   563566

# %%
##not suitable for unstructed datasets
#dataframe
#first record goes to column name, header=infer

# %%
type(pd.read_csv('sample_test.csv'))
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_csv('sample_test.csv',header=None)
# Out:
#           0          1        2        3        4
# 0      name    emailid  address  pincode  sirname
# 1    aditya      a@1.c    kanke   834006     aman
# 2      aman      b@2.c   ranchi   834001      lol
# 3  ass;ljf;  dla;slkas   spkpsf   563566

# %%
pd.read_csv('sample_test.csv',names=['a','b','c','d','e','f'])
# Out:
#           a          b        c        d        e   f
# 0      name    emailid  address  pincode  sirname NaN
# 1    aditya      a@1.c    kanke   834006     aman NaN
# 2      aman      b@2.c   ranchi   834001      lol NaN
# 3  ass;ljf;  dla;slkas   spkpsf   563566          NaN

# %%
pd.read_csv('sample_test.csv',names=['a','b','c'])
# Out:
#                           a        b        c
# name     emailid    address  pincode  sirname
# aditya   a@1.c        kanke   834006     aman
# aman     b@2.c       ranchi   834001      lol
# ass;ljf; dla;slkas   spkpsf   563566

# %%
pd.read_csv('sample_test.csv')
# Out:
#   name@emailid@address@pincode@sirname
# 0       aditya@a@1.c@kanke@834006@aman
# 1         aman@b@2.c@ranchi@834001@lol
# 2   ass;ljf;@dla;slkas@spkpsf@563566@

# %%
df=pd.read_csv('sample_test.csv')

# %%
df
# Out:
#        name    emailid address  pincode sirname
# 0    aditya      a@1.c   kanke   834006    aman
# 1      aman      b@2.c  ranchi   834001     lol
# 2  ass;ljf;  dla@slkas  spkpsf   563566

# %%
df=pd.read_csv('sample_test.csv',skiprows=[2])

# %%
df
# Out:
#        name    emailid address  pincode sirname
# 0    aditya      a@1.c   kanke   834006    aman
# 1  ass;ljf;  dla@slkas  spkpsf   563566

# %%
df.dtypes
# Out:
# name       object
# emailid    object
# address    object
# pincode     int64
# sirname    object
# dtype: object

# %%
#string - object

# %%
df.head()
#show 5 records
# Out:
#        name    emailid address  pincode sirname
# 0    aditya      a@1.c   kanke   834006    aman
# 1  ass;ljf;  dla@slkas  spkpsf   563566

# %%
df.head(2)
# Out:
#        name    emailid address  pincode sirname
# 0    aditya      a@1.c   kanke   834006    aman
# 1  ass;ljf;  dla@slkas  spkpsf   563566

# %%
df.tail(1)
# Out:
#        name    emailid address  pincode sirname
# 1  ass;ljf;  dla@slkas  spkpsf   563566

# %%
df=pd.read_csv('123.csv')

# %%
df.tail()
# Out:
#      Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 5435     BDCQ.SF8RSCA  2020.12     522.330         NaN      F  Dollars
# 5436     BDCQ.SF8RSCA  2021.03     597.997         NaN      F  Dollars
# 5437     BDCQ.SF8RSCA  2021.06     635.931         NaN      F  Dollars
# 5438     BDCQ.SF8RSCA  2021.09     382.195         NaN      R  Dollars
# 5439     BDCQ.SF8RSCA  2021.12     397.184         NaN      F  Dollars
#
#       Magnitude                         Subject  \
# 5435          6  Business Data Collection - BDC
# 5436          6  Business Data Collection - BDC
# 5437          6  Business Data Collection - BDC
# 5438          6  Business Data Collection - BDC
# 5439          6  Business Data Collection - BDC
#
#                                                 Group    Series_title_1  \
# 5435  Industry by financial variable (NZSIOC Level 1)  Operating profit
# 5436  Industry by financial variable (NZSIOC Level 1)  Operating profit
# ...

# %%
df.dtypes
# Out:
# Series_reference     object
# Period              float64
# Data_value          float64
# Suppressed          float64
# STATUS               object
# UNITS                object
# Magnitude             int64
# Subject              object
# Group                object
# Series_title_1       object
# Series_title_2       object
# Series_title_3       object
# Series_title_4       object
# Series_title_5      float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Series_reference', 'Period', 'Data_value', 'Suppressed', 'STATUS',
#        'UNITS', 'Magnitude', 'Subject', 'Group', 'Series_title_1',
#        'Series_title_2', 'Series_title_3', 'Series_title_4', 'Series_title_5'],
#       dtype='object')

# %%
df['Subject']
#select * from
# Out:
# 0       Business Data Collection - BDC
# 1       Business Data Collection - BDC
# 2       Business Data Collection - BDC
# 3       Business Data Collection - BDC
# 4       Business Data Collection - BDC
#                      ...
# 5435    Business Data Collection - BDC
# 5436    Business Data Collection - BDC
# 5437    Business Data Collection - BDC
# 5438    Business Data Collection - BDC
# 5439    Business Data Collection - BDC
# Name: Subject, Length: 5440, dtype: object

# %%
a=df["Period"]

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
df['Subject','Period']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Subject', 'Period')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df1=df[['Subject','Period']]

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df[['Subject']])
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_excel('excel.xlsx')
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0          NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN
# 12         NaN         NaN         NaN         NaN
# 13         NaN         NaN         NaN         NaN
# 14         NaN         NaN         NaN         NaN
# 15         NaN         NaN         NaN         NaN
# 16         NaN         NaN         NaN         NaN
# ...

# %%
#reads first sheet

# %%
df=pd.read_excel('excel.xlsx')

# %%
df.keys()
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12'],
#       dtype='object')

# %%
df=pd.ExcelFile('excel.xlsx')

# %%
df.sheet_names
# Out:
# ['Create Portfolio',
#  'Introduction',
#  'Create your instrument universe',
#  'Add your take on balances',
#  'Create your test environment',
#  'Make live trades in production',
#  'Add some test transactions',
#  'Inputs']

# %%
for i in df.sheet_names:
    pd.read_excel('excel.xlsx',sheet_name=i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1892/3208664775.py in <module>
# ----> 1 for i in df.sheet_names:
#       2     pd.read_excel('excel.xlsx',sheet_name=i)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sheet_names'

# %%
pd.read_excel('excel.xlsx',sheet_name='Add your take on balances')
# Out:
#     Unnamed: 0  Unnamed: 1                                         Unnamed: 2  \
# 0          NaN         NaN                                                NaN
# 1          NaN         NaN                                                NaN
# 2          NaN         NaN                                                NaN
# 3          NaN         NaN                                                NaN
# 4          NaN         NaN                                                NaN
# 5          NaN         NaN                                                NaN
# 6          NaN         NaN                                                NaN
# 7          NaN         NaN                                                NaN
# 8          NaN         NaN                                                NaN
# 9          NaN         NaN                                                NaN
# 10         NaN         NaN                                                NaN
# ...

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
