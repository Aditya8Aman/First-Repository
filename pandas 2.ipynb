# %%
import pandas as pd

# %%
df=pd.read_html('http://www.basketball-reference.com/leagues/NBA_2015_totals.html')
#scrap only tabular data

# %%
type(df)
# Out:
# list

# %%
df
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# dataframe at zeroth index

# %%
d1=df[0]

# %%
d1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
d1.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
d1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
d1[['Age','GS']]
# Out:
#     Age  GS
# 0    24  22
# 1    20   0
# 2    21  67
# 3    28   0
# 4    29  72
# ..   ..  ..
# 670  26  68
# 671  26  48
# 672  26  20
# 673  22  45
# 674  25  59
#
# [675 rows x 2 columns]

# %%
d1.to_csv('NBA.csv')

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 44BD-A86A
#
#  Directory of C:\Users\MSI\Untitled Folder
#
# 04/28/2022  09:05 AM    <DIR>          .
# 04/28/2022  09:05 AM    <DIR>          ..
# 04/28/2022  08:51 AM    <DIR>          .ipynb_checkpoints
# 04/26/2022  09:05 PM         1,126,526 123.csv
# 04/26/2022  09:03 PM         1,126,526 123.csv.csv
# 04/26/2022  09:04 PM    <DIR>          business-financial-data-december-2021-quarter-csv
# 04/26/2022  09:03 PM            50,120 business-financial-data-december-2021-quarter-csv.zip
# 04/26/2022  08:50 PM             3,175 Cassandra.ipynb
# 04/27/2022  12:29 PM           161,651 excel.xlsx
# 04/25/2022  01:05 PM             8,192 ineuron.db
# 04/25/2022  01:42 PM            12,288 join.db
# 04/25/2022  01:45 PM             8,720 join.db-journal
# 04/11/2022  08:26 AM            12,288 joindb.db
# 04/25/2022  01:06 PM             8,720 joindb.db-journal
# 04/04/2022  03:08 PM            19,796 Mongodb.ipynb
# ...

# %%
d1.to_csv('NBAnoHEAder',index=False)

# %%
df=pd.read_html('https://stats.espncricinfo.com/ci/content/records/83548.html')

# %%
df2=df[0]

# %%
df2
# Out:
#                          Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0          SR Tendulkar (INDIA)  1989-2012  463   452  41  18426  200*  44.83
# 1   KC Sangakkara (Asia/ICC/SL)  2000-2015  404   380  41  14234   169  41.98
# 2          RT Ponting (AUS/ICC)  1995-2012  375   365  39  13704   164  42.03
# 3       ST Jayasuriya (Asia/SL)  1989-2011  445   433  18  13430   189  32.36
# 4    DPMD Jayawardene (Asia/SL)  1998-2015  448   418  39  12650   144  33.37
# ..                          ...        ...  ...   ...  ..    ...   ...    ...
# 87               JP Duminy (SA)  2004-2019  199   179  40   5117  150*  36.81
# 88         PD Collingwood (ENG)  2001-2011  197   181  37   5092  120*  35.36
# 89              A Symonds (AUS)  1998-2009  198   161  33   5088   156  39.75
# 90      Abdul Razzaq (Asia/PAK)  1996-2011  265   228  57   5080   112  29.70
# 91            PR Stirling (IRE)  2008-2022  136   133   3   5047   177  38.82
#
# ...

# %%
len(df)
# Out:
# 3

# %%
df[0]
# Out:
#                          Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0          SR Tendulkar (INDIA)  1989-2012  463   452  41  18426  200*  44.83
# 1   KC Sangakkara (Asia/ICC/SL)  2000-2015  404   380  41  14234   169  41.98
# 2          RT Ponting (AUS/ICC)  1995-2012  375   365  39  13704   164  42.03
# 3       ST Jayasuriya (Asia/SL)  1989-2011  445   433  18  13430   189  32.36
# 4    DPMD Jayawardene (Asia/SL)  1998-2015  448   418  39  12650   144  33.37
# ..                          ...        ...  ...   ...  ..    ...   ...    ...
# 87               JP Duminy (SA)  2004-2019  199   179  40   5117  150*  36.81
# 88         PD Collingwood (ENG)  2001-2011  197   181  37   5092  120*  35.36
# 89              A Symonds (AUS)  1998-2009  198   161  33   5088   156  39.75
# 90      Abdul Razzaq (Asia/PAK)  1996-2011  265   228  57   5080   112  29.70
# 91            PR Stirling (IRE)  2008-2022  136   133   3   5047   177  38.82
#
# ...

# %%
df[1]
# Out:
#                                                    0
# 0  By default, the shading indicates records from...
# 1  Adjust:  most recent  | past week  | past mont...

# %%
df[2]
# Out:
#                                                    0
# 0  Records includes the following current or rece...
# 1  Oman v Papua New Guinea at Dubai (DSC), ICC Me...
# 2  Oman v Scotland at Dubai (DSC), ICC Men's Cric...
# 3  Papua New Guinea v Scotland at Dubai (DSC), IC...

# %%
df2.to_csv('mostruns.csv')

# %% [markdown]
# ocr??

# %%
d='''
    {"name":"Aditya Aman",
    "email_id": "abc@123.com",
    "tech":["ML","Dl","CV","NLP","RL","BD","DA"],
    "platform":["ineuron","coursera","youtube"]
    }'''

#convert this in tabular or structured format
#json javascript Object Notation, dictionary format

# %%
import json

# %%
a=json.loads(d)

# %%
a
# Out:
# {'name': 'Aditya Aman',
#  'email_id': 'abc@123.com',
#  'tech': ['ML', 'Dl', 'CV', 'NLP', 'RL', 'BD', 'DA'],
#  'platform': ['ineuron', 'coursera', 'youtube']}

# %%
type(a)
# Out:
# dict

# %%
type(d)
# Out:
# str

# %%
pd.read_json(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8324/191295205.py in <module>
# ----> 1 pd.read_json(a)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
d1='''
    {"name":"Aditya Aman",
    "email_id": "abc@123.com",
    "tech":["ML","Dl","CV"],
    "platform":["ineuron","coursera","youtube"]
    }'''

# %%
a1=json.loads(d1)

# %%
a1
# Out:
# {'name': 'Aditya Aman',
#  'email_id': 'abc@123.com',
#  'tech': ['ML', 'Dl', 'CV'],
#  'platform': ['ineuron', 'coursera', 'youtube']}

# %%
pd.DataFrame(a1)
# Out:
#           name     email_id tech  platform
# 0  Aditya Aman  abc@123.com   ML   ineuron
# 1  Aditya Aman  abc@123.com   Dl  coursera
# 2  Aditya Aman  abc@123.com   CV   youtube

# %% [markdown]
# list values should have same no of entries

# %%
pd.DataFrame(a1['tech'])
# Out:
#     0
# 0  ML
# 1  Dl
# 2  CV

# %%
a1['tech']
# Out:
# ['ML', 'Dl', 'CV']

# %%
pd.DataFrame(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8324/516763050.py in <module>
# ----> 1 pd.DataFrame(a)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
# ...

# %%
del a['platform']

# %%
pd.DataFrame(a)
# Out:
#           name     email_id tech
# 0  Aditya Aman  abc@123.com   ML
# 1  Aditya Aman  abc@123.com   Dl
# 2  Aditya Aman  abc@123.com   CV
# 3  Aditya Aman  abc@123.com  NLP
# 4  Aditya Aman  abc@123.com   RL
# 5  Aditya Aman  abc@123.com   BD
# 6  Aditya Aman  abc@123.com   DA

# %%
pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %% [markdown]
# pd.read_json try to convert into Dataframe

# %%
import requests
url ='https://api.github.com/repos/pandas-dev/pandas/issues'

# %%
data = requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data1=data.json()

# %%
data1
#raw data from the url
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46886',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46886/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46886/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46886/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46886',
#   'id': 1217903962,
#   'node_id': 'PR_kwDOAA0YD84250bm',
#   'number': 46886,
#   'title': 'REF: handle 2D in tslibs.vectorized',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
# ...

# %%
type(data1)
# Out:
# list

# %%
len(data1)
# Out:
# 30

# %%
data1[0]['user']['id']
# Out:
# 8078968

# %%
for i in range(0,len(data1)):
    print(data1[i]['user']['id'])
# Out:
# 8078968
# 5768348
# 197589
# 88171669
# 5019367
# 5768348
# 11664259
# 66732186
# 20391209
# 7558201
# 3409997
# 53195438
# 7455396
# 43210452
# 33491632
# 433383
# 93147076
# 46936498
# 13811914
# 3938751
# 10647082
# 3589536
# 45562402
# 6398777
# 5019367
# 53005533
# 53806545
# 73769392
# 8078968
# 8078968

# %%
df2=pd.DataFrame(data1, columns=['url', 'comments','url','id','user'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7240/926815260.py in <module>
# ----> 1 df2=pd.DataFrame(data1, columns=['url', 'comments','url','id','user'])
#
# NameError: name 'data1' is not defined

# %%
df2.to_csv('json1.csv')
